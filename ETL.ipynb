# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
# Se carga el dataset en excel de Accidentes mortales
data= pd.read_excel('data/Transportation & Logistics Tracking Dataset.xlsx', sheet_name=None)

# %%
# Se muestran las hojas del excel
print(data.keys())
# Out:
# dict_keys(['Primary Data', 'Data Dictionary'])

# %%
df_tracking= data['Primary Data']

# %%
df_tracking.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3585 entries, 0 to 3584
# Data columns (total 28 columns):
#  #   Column                              Non-Null Count  Dtype
# ---  ------                              --------------  -----
#  0   Gps Provider                        3585 non-null   object
#  1   Booking ID                          3585 non-null   object
#  2   Shipment Type                       3585 non-null   object
#  3   Booking Date                        3585 non-null   datetime64[ns]
#  4   Vehicle Registration                3585 non-null   object
#  5   Origin Location                     3585 non-null   object
#  6   Destination Location                3585 non-null   object
#  7   Origin Location Latitude            3585 non-null   float64
#  8   Origin Location Longitude           3585 non-null   float64
#  9   Destination Location Latitude       3585 non-null   float64
#  10  Destination Location Longitude      3585 non-null   float64
# ...

# %%
df_tracking.head(1)
# Out:
#     Gps Provider    Booking ID Shipment Type        Booking Date  \
# 0  Consent Track  AEIBK2027469       Regular 2020-08-26 12:03:46
#
#   Vehicle Registration           Origin Location  \
# 0           MH14GD9464  Shive, Pune, Maharashtra
#
#               Destination Location  Origin Location Latitude  \
# 0  Pondur, Kanchipuram, Tamil Nadu                 18.750621
#
#    Origin Location Longitude  Destination Location Latitude  ...  \
# 0                   73.87719                      12.930429  ...
#
#        Trip Start Date        Trip End Date Transportation Distance (KM)  \
# 0  2020-08-26 16:16:00  2020-08-28 12:15:10                       1290.0
#
#                   Vehicle Type Minimum Kms To Be Covered In A Day  \
# 0  32 FT Multi-Axle 14MT - HCV                                NaN
#
#        Driver Name  Driver Mobile No  \
# 0  VIRAT NILAPALLE      9.960008e+09
#
#                               Customer Name          Supplier Name  \
# ...

# %%
columnas= ['Gps Provider','Shipment Type', 'Vehicle Type']
total_Viajes= df_tracking['Booking ID'].count()

for col in columnas:    
    # Calcular porcentajes
    contador = df_tracking[col].value_counts()
    porcentajes = (contador / total_Viajes) * 100

    # Dibuja un grafico por cada Columna
    plt.figure(figsize=(6, 7))
    ax = sns.barplot(y=porcentajes.index, x=porcentajes.values, orient='h')
    plt.ylabel('Categoria')
    plt.xlabel('Porcentaje')
    plt.title(col)
    
    #Dibuja los porcentajes en cada barra
    for i, valor in enumerate(porcentajes):
        plt.text(valor, i, f'{valor:.1f}%', ha='left', va='center')
    
    plt.xlim(0, 100)
    plt.show()

# %%
df_tracking['Booking ID'].value_counts()
# Out:
# Booking ID
# MVCV0000798/082021    3
# MVCV0000759/082021    2
# AEIBK2027469          1
# AEIBK2019797          1
# AEIBK2017652          1
#                      ..
# AEIBK2025707          1
# AEIBK2025332          1
# AEIBK2025516          1
# AEIBK2025706          1
# WDSBKTP44502          1
# Name: count, Length: 3582, dtype: int64

# %%
df_tracking = df_tracking.drop_duplicates(subset=['Booking ID'])
df_tracking['Booking ID'].value_counts()
# Out:
# Booking ID
# AEIBK2027469    1
# AEIBK2017791    1
# AEIBK2022034    1
# AEIBK2017628    1
# AEIBK2017652    1
#                ..
# AEIBK2025115    1
# AEIBK2025707    1
# AEIBK2025332    1
# AEIBK2025516    1
# WDSBKTP44502    1
# Name: count, Length: 3582, dtype: int64
